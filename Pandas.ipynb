# %%
import pandas as pd
data = pd.read_csv('lsd_math_score_data.csv')
data
# Out:
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score
# 0                      5     1.17                78.93
# 1                     15     2.97                58.20
# 2                     30     3.26                67.47
# 3                     60     4.69                37.47
# 4                    120     5.83                45.65
# 5                    240     6.00                32.92
# 6                    480     6.41                29.97

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data['Avg_Math_Test_Score']
# Out:
# 0    78.93
# 1    58.20
# 2    67.47
# 3    37.47
# 4    45.65
# 5    32.92
# 6    29.97
# Name: Avg_Math_Test_Score, dtype: float64

# %%
data['Subject'] = 'Advanced JAVA'

# %%
data
# Out:
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score        Subject
# 0                      5     1.17                78.93  Advanced JAVA
# 1                     15     2.97                58.20  Advanced JAVA
# 2                     30     3.26                67.47  Advanced JAVA
# 3                     60     4.69                37.47  Advanced JAVA
# 4                    120     5.83                45.65  Advanced JAVA
# 5                    240     6.00                32.92  Advanced JAVA
# 6                    480     6.41                29.97  Advanced JAVA

# %%
data['High Score'] = 100
data
# Out:
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score        Subject  \
# 0                      5     1.17                78.93  Advanced JAVA
# 1                     15     2.97                58.20  Advanced JAVA
# 2                     30     3.26                67.47  Advanced JAVA
# 3                     60     4.69                37.47  Advanced JAVA
# 4                    120     5.83                45.65  Advanced JAVA
# 5                    240     6.00                32.92  Advanced JAVA
# 6                    480     6.41                29.97  Advanced JAVA
#
#    High Score
# 0         100
# 1         100
# 2         100
# 3         100
# 4         100
# 5         100
# 6         100

# %%
data['High Score'] = data['High Score'] + data['Avg_Math_Test_Score']
data
# Out:
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score        Subject  \
# 0                      5     1.17                78.93  Advanced JAVA
# 1                     15     2.97                58.20  Advanced JAVA
# 2                     30     3.26                67.47  Advanced JAVA
# 3                     60     4.69                37.47  Advanced JAVA
# 4                    120     5.83                45.65  Advanced JAVA
# 5                    240     6.00                32.92  Advanced JAVA
# 6                    480     6.41                29.97  Advanced JAVA
#
#    High Score
# 0      178.93
# 1      158.20
# 2      167.47
# 3      137.47
# 4      145.65
# 5      132.92
# 6      129.97

# %%
data['High Score'] =
